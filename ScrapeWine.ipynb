# %%
# import library to request data from URL
import requests 
# import "regular expressions" for removing extra spaces 
import re
# import pandas (staple data science library!)
import pandas as pd
# import Soup for scraping 
from bs4 import BeautifulSoup

# Request the page of red wines from BottleRocket
red_wine_data = requests.get("https://www.bottlerocket.com/wine/category/red-wine.html?product_list_limit=all").content
# Create a Soup object using the HTML data that comes back 
soup = BeautifulSoup(red_wine_data, 'html.parser')
# Find all of the products on the page 
products = find_all('div', class_="product-item-details")

# %%
# Empty list that we will add to as we loop 
rows = []

# Iterate over each product that Soup found 
for p in products:
    # Get the name
    name = p.find('span', itemprop="name").text
    # Get the vintage
    vintage = p.find("li", class_="product_vintage").find('a').text
    # Replace extra spaces in middle of sentence using re library, then strip the trailing and leading spaces off the sentence as well
    # strip("   Hello There!     ") = "Hello There!"
    vintage = re.sub(' +', ' ', vintage).strip()
    # Get the variety of grape
    grapes = p.find("li", class_="product_grapes").text.strip()
    # Get the country/region 
    region = p.find("li", class_="product_country").text.strip()
    # Get the details of the wine, the "product_brief"
    brief = p.find("li", class_="product_brief").text
    brief = re.sub(' +', ' ', brief).strip()
    # Separate/split on the comma into separate variables 
    color, dry_level, body, taste1 = brief.split(',')[0:4]
    # Add the row to list we declared earlier (think of this add adding a row to a spread sheet)
    rows.append( [name, vintage, grapes, country, brief, color, dry_level, body, taste1, taste2] )

# Create a DataFrame (Spreadsheet equivalent in code)
# Just specify the data and the names of the columns 
df = pd.DataFrame(data=rows, columns=['name', 'vintage', 'grape_variety', 'region', 'tags', 'color', 'dryness', 'body', 'taste1', 'taste2'])

# %%
# Display the data!
df
# Out:
#                                name  \
# 0                   Camins 2 Dreams
# 1                  Domaine Faiveley
# 2                     Bodegas Ponce
# 3                      Evening Land
# 4                       Maison Noir
# 5                          Nomadica
# 6                              Kita
# 7    Domaine de la Vieille Julienne
# 8                Folly of the Beast
# 9                           Felsina
# 10                Tenuta San Jacopo
# 11          Les Vignerons Parisiens
# 12               Figli Luigi Oddero
# 13                 Domaine d'Ardhuy
# 14                        Caiarossa
# 15                       Avignonesi
# 16                           Lafken
# 17    Chateau La Pierre du Marechal
# 18                  Vinos Malaparte
# 19                     Elvio Cogno
# 20                  Domaine Ramonet
# 21                  Domaine Ramonet
# 22                 Domaine Lamarche
# 23             Domaine J.F. Mugnier
# 24            Domaine de Beaurenard
# 25                  Villa Michelino
# 26                   Fritz Windisch
# 27            Moulin de la Roquille
# 28           Domaine de la Rectorie
# 29              Chateau Mont Thabor
# ..                              ...
# 167            Flechas de los Andes
# 168               Underwood Cellars
# 169                         Viviani
# 170                           Moric
# 171                   Au Bon Climat
# 172                      Vina Leyda
# 173                       il Faggio
# 174               Domaine du Castel
# 175                         Odfjell
# 176                         Jam Jar
# 177             Chateau la Bonnelle
# 178                       Excelsior
# 179                   Three Thieves
# 180     Domaine du Vieux Telegraphe
# 181               Tenuta di Trinoro
# 182       Bodegas Hijos de Juan Gil
# 183               Cakebread Cellars
# 184                          Bob's
# 185                   Bodegas Breca
# 186                   Weinhof Scheu
# 187                    Manischewitz
# 188                      Plumpjack
# 189                    Il Palazzone
# 190                      Silver Oak
# 191                        Lemelson
# 192                     Michel Tete
# 193                        Bonterra
# 194                          Ramsay
# 195                           Ridge
# 196                          Crosby
#
# 28                              Grenache, Carignan
# 29                      Grenache, Syrah, Mourvedre
# ..                                             ...
# 167                                         Malbec
# 168                                     Pinot Noir
# 169                            Corvina, Rondinella
# 170                                  Blaufränkisch
# 171                                     Pinot Noir
# 172                                     Pinot Noir
# 173                                  Montepulciano
# 174      Cabernet Sauvignon, Merlot, Petite Verdot
# 175                                       Carignan
# 176                                          Syrah
# 177                         Merlot, Cabernet Franc
# 178                                          Syrah
# 179                             Cabernet Sauvignon
# 180           Grenache, Mourvèdre, Syrah, Cinsault
# 181  Cabernet Franc, Merlot, Cabernet Sauvignon...
# 182                                     Monastrell
# 183  Cabernet Sauvignon, Merlot, Cabernet Franc...
# 184                                       Pinotage
# 185                                       Grenache
# 186                                     Pinot Noir
# 187                                        Concord
# 188                             Cabernet Sauvignon
# 189                              Sangiovese Grosso
# 190                             Cabernet Sauvignon
# 191                                     Pinot Noir
# 192                                          Gamay
# 193                                         Merlot
# 194                                     Pinot Noir
# 195          Zinfandel, Carignane, Petite Sirah...
# 196                             Cabernet Sauvignon
#
#                           origin  \
# 0            U.S.A. > California
# 1              France > Burgundy
# 2                          Spain
# 3                U.S.A. > Oregon
# 4                U.S.A. > Oregon
# 5            U.S.A. > California
# 6            U.S.A. > California
# 7                 France > Rhone
# 8            U.S.A. > California
# 9                Italy > Tuscany
# 10               Italy > Tuscany
# 11                        France
# 12              Italy > Piedmont
# 13             France > Burgundy
# 14               Italy > Tuscany
# 15               Italy > Tuscany
# 16          Chile > Maipo Valley
# 17             France > Bordeaux
# 18       Spain > Castilla y Léon
# 19              Italy > Piedmont
# 20             France > Burgundy
# 21             France > Burgundy
# 22             France > Burgundy
# 23             France > Burgundy
# 24                France > Rhone
# 25              Italy > Piedmont
# 26         Germany > Rheinhessen
# 27             France > Bordeaux
# 28                        France
# 29                France > Rhone
# ..                           ...
# 167          Argentina > Mendoza
# 168              U.S.A. > Oregon
# 169               Italy > Veneto
# 170         Austria > Burgenland
# 171          U.S.A. > California
# 172          Chile > San Antonio
# 173              Italy > Abruzzo
# 174        Israel > Judean Hills
# 175         Chile > Maule Valley
# 176  South Africa > Western Cape
# 177            France > Bordeaux
# 178  South Africa > Western Cape
# 179          U.S.A. > California
# 180               France > Rhone
# 181              Italy > Tuscany
# 182               Spain > Murcia
# 183          U.S.A. > California
# 184  South Africa > Western Cape
# 185               Spain > Aragon
# 186              Germany > Pfalz
# 187            U.S.A. > New York
# 188          U.S.A. > California
# 189              Italy > Tuscany
# 190          U.S.A. > California
# 191              U.S.A. > Oregon
# 192            France > Burgundy
# 193          U.S.A. > California
# 194          U.S.A. > California
# 195          U.S.A. > California
# 196          U.S.A. > California
#
#                                                tags color       dryness  \
# 0           Red, Dry, Medium-Bodied, Spicy, Vibrant   Red           Dry
# 1             Red, Dry, Medium-Bodied, Floral, Rich   Red           Dry
# 2          Red, Dry, Full-Bodied, Mineral, Muscular   Red           Dry
# 3             Red, Dry, Medium-Bodied, Floral, Rich   Red           Dry
# 4             Red, Dry, Full-Bodied, Fruity, Hearty   Red           Dry
# 5          Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
# 6          Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
# 7             Red, Dry, Full-Bodied, Fruity, Hearty   Red           Dry
# 8            Red, Dry, Medium-Bodied, Fruity, Fresh   Red           Dry
# 9                     Red, Dry, Full-Bodied, Fruity   Red           Dry
# 10          Red, Dry, Medium-Bodied, Floral, Hearty   Red           Dry
# 11           Red, Dry, Medium-Bodied, Spicy, Hearty   Red           Dry
# 12                  Red, Dry, Medium-Bodied, Floral   Red           Dry
# 13         Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
# 14             Red, Dry, Full-Bodied, Spicy, Hearty   Red           Dry
# 15                    Red, Dry, Full-Bodied, Fruity   Red           Dry
# 16            Red, Dry, Full-Bodied, Fruity, Hearty   Red           Dry
# 17            Red, Dry, Medium-Bodied, Earthy, Soft   Red           Dry
# 18                 Red, Dry, Medium-Bodied, Mineral   Red           Dry
# 19                  Red, Dry, Medium-Bodied, Earthy   Red           Dry
# 20            Red, Dry, Medium-Bodied, Floral, Rich   Red           Dry
# 21                  Red, Dry, Medium-Bodied, Fruity   Red           Dry
# 22            Red, Dry, Medium-Bodied, Fruity, Rich   Red           Dry
# 23                  Red, Dry, Medium-Bodied, Earthy   Red           Dry
# 24            Red, Dry, Full-Bodied, Fruity, Hearty   Red           Dry
# 25            Red, Dry, Medium-Bodied, Floral, Lean   Red           Dry
# 26   Red, Touch Sweet, Medium-Bodied, Fruity, Fresh   Red   Touch Sweet
# 27            Red, Dry, Medium-Bodied, Fruity, Rich   Red           Dry
# 28                  Red, Dry, Medium-Bodied, Fruity   Red           Dry
# 29          Red, Dry, Full-Bodied, Fruity, Muscular   Red           Dry
# ..                                              ...   ...           ...
# 167         Red, Dry, Full-Bodied, Fruity, Muscular   Red           Dry
# 168           Red, Dry, Light-Bodied, Fruity, Fresh   Red           Dry
# 169                   Red, Dry, Full-Bodied, Fruity   Red           Dry
# 170        Red, Dry, Medium-Bodied, Earthy, Vibrant   Red           Dry
# 171          Red, Dry, Medium-Bodied, Fruity, Fresh   Red           Dry
# 172          Red, Dry, Medium-Bodied, Fruity, Fresh   Red           Dry
# 173        Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
# 174          Red, Dry, Medium-Bodied, Mineral, Rich   Red           Dry
# 175           Red, Dry, Medium-Bodied, Earthy, Rich   Red           Dry
# 176  Red, Touch Sweet, Medium-Bodied, Fruity, Jammy   Red   Touch Sweet
# 177           Red, Dry, Medium-Bodied, Earthy, Rich   Red           Dry
# 178           Red, Dry, Full-Bodied, Fruity, Hearty   Red           Dry
# 179           Red, Dry, Medium-Bodied, Fruity, Soft   Red           Dry
# 180         Red, Dry, Full-Bodied, Earthy, Muscular   Red           Dry
# 181             Red, Dry, Full-Bodied, Fruity, Rich   Red           Dry
# 182             Red, Dry, Full-Bodied, Fruity, Rich   Red           Dry
# 183             Red, Dry, Full-Bodied, Fruity, Rich   Red           Dry
# 184           Red, Dry, Medium-Bodied, Fruity, Soft   Red           Dry
# 185            Red, Dry, Full-Bodied, Fruity, Dense   Red           Dry
# 186        Red, Dry, Light-Bodied, Mineral, Vibrant   Red           Dry
# 187          Red, Sweet, Full-Bodied, Fruity, Dense   Red         Sweet
# 188             Red, Dry, Full-Bodied, Fruity, Rich   Red           Dry
# 189         Red, Dry, Full-Bodied, Fruity, Muscular   Red           Dry
# 190             Red, Dry, Full-Bodied, Fruity, Rich   Red           Dry
# 191           Red, Dry, Medium-Bodied, Earthy, Rich   Red           Dry
# 192           Red, Dry, Light-Bodied, Fruity, Crisp   Red           Dry
# 193           Red, Dry, Medium-Bodied, Fruity, Soft   Red           Dry
# 194        Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
# 195                   Red, Dry, Full-Bodied, Fruity   Red           Dry
# 196        Red, Dry, Medium-Bodied, Fruity, Vibrant   Red           Dry
#
#                body    taste1  taste2
# 0     Medium-Bodied     Spicy   Fresh
# 1     Medium-Bodied    Floral   Fresh
# 2       Full-Bodied   Mineral   Fresh
# 3     Medium-Bodied    Floral   Fresh
# 4       Full-Bodied    Fruity   Fresh
# 5     Medium-Bodied    Fruity   Fresh
# 6     Medium-Bodied    Fruity   Fresh
# 7       Full-Bodied    Fruity   Fresh
# 8     Medium-Bodied    Fruity   Fresh
# 9       Full-Bodied    Fruity   Fresh
# 10    Medium-Bodied    Floral   Fresh
# 11    Medium-Bodied     Spicy   Fresh
# 12    Medium-Bodied    Floral   Fresh
# 13    Medium-Bodied    Fruity   Fresh
# 14      Full-Bodied     Spicy   Fresh
# 15      Full-Bodied    Fruity   Fresh
# 16      Full-Bodied    Fruity   Fresh
# 17    Medium-Bodied    Earthy   Fresh
# 18    Medium-Bodied   Mineral   Fresh
# 19    Medium-Bodied    Earthy   Fresh
# 20    Medium-Bodied    Floral   Fresh
# 21    Medium-Bodied    Fruity   Fresh
# 22    Medium-Bodied    Fruity   Fresh
# 23    Medium-Bodied    Earthy   Fresh
# 24      Full-Bodied    Fruity   Fresh
# 25    Medium-Bodied    Floral   Fresh
# 26    Medium-Bodied    Fruity   Fresh
# 27    Medium-Bodied    Fruity   Fresh
# 28    Medium-Bodied    Fruity   Fresh
# 29      Full-Bodied    Fruity   Fresh
# ..              ...       ...     ...
# 167     Full-Bodied    Fruity   Fresh
# 168    Light-Bodied    Fruity   Fresh
# 169     Full-Bodied    Fruity   Fresh
# 170   Medium-Bodied    Earthy   Fresh
# 171   Medium-Bodied    Fruity   Fresh
# 172   Medium-Bodied    Fruity   Fresh
# 173   Medium-Bodied    Fruity   Fresh
# 174   Medium-Bodied   Mineral   Fresh
# 175   Medium-Bodied    Earthy   Fresh
# 176   Medium-Bodied    Fruity   Fresh
# 177   Medium-Bodied    Earthy   Fresh
# 178     Full-Bodied    Fruity   Fresh
# 179   Medium-Bodied    Fruity   Fresh
# 180     Full-Bodied    Earthy   Fresh
# 181     Full-Bodied    Fruity   Fresh
# 182     Full-Bodied    Fruity   Fresh
# 183     Full-Bodied    Fruity   Fresh
# 184   Medium-Bodied    Fruity   Fresh
# 185     Full-Bodied    Fruity   Fresh
# 186    Light-Bodied   Mineral   Fresh
# 187     Full-Bodied    Fruity   Fresh
# 188     Full-Bodied    Fruity   Fresh
# 189     Full-Bodied    Fruity   Fresh
# 190     Full-Bodied    Fruity   Fresh
# 191   Medium-Bodied    Earthy   Fresh
# 192    Light-Bodied    Fruity   Fresh
# 193   Medium-Bodied    Fruity   Fresh
# 194   Medium-Bodied    Fruity   Fresh
# 195     Full-Bodied    Fruity   Fresh
# 196   Medium-Bodied    Fruity   Fresh
#
# [197 rows x 10 columns]
